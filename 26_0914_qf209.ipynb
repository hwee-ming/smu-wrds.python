# %% [markdown]
# <a href="https://colab.research.google.com/github/hwee-ming/smu-wrds.python/blob/main/26_0914_qf209.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### START

# %%
pip install wrds

# %%
import wrds
db = wrds.Connection()
# Out:
# Enter your WRDS username [root]:hmlim
# Enter your password:··········
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?: n
# You can create this file yourself at any time with the create_pgpass_file() function.
# Loading library list...
# Done

# %%
#import wrds
#db = wrds.Connection()
lib = db.list_libraries()
lib
#sorted(lib)
# Out:
# ['aha',
#  'aha_common',
#  'aha_hcris_recent',
#  'aha_it_survey_recent',
#  'aha_sample',
#  'ahasamp',
#  'altrata_exec_samp',
#  'altsamp',
#  'audit',
#  'audit_acct_os',
#  'audit_audit_comp',
#  'audit_common',
#  'audit_corp_legal',
#  'auditsmp',
#  'auditsmp_all',
#  'bank',
#  'bank_all',
#  'bank_premium_samp',
#  'banksamp',
#  'block',
#  'block_all',
#  'boardex',
#  'boardex_eur',
#  'boardex_na',
#  'boardex_row',
#  'boardex_trial',
#  'boardex_uk',
#  'boardsmp',
#  'bvd',
#  'bvd_amadeus_trial',
#  'bvd_bvdbankf_trial',
#  'bvd_orbis_large',
#  'bvd_orbis_medium',
#  'bvd_orbis_small',
#  'bvd_orbis_trial',
#  'bvdsamp',
#  'calcbench_trial',
#  'calcbnch',
#  'candid_samp',
#  'cboe',
#  'cboe_all',
#  'cboe_sample',
#  'cboesamp',
#  'cddsamp',
#  'ciq',
#  'ciq_common',
#  'ciq_pplintel',
#  'ciq_ratings',
#  'ciq_transcripts',
#  'ciqsamp',
#  'ciqsamp_capstrct',
#  'ciqsamp_common',
#  'ciqsamp_keydev',
#  'ciqsamp_pplintel',
#  'ciqsamp_ratings',
# ...

# %% [markdown]
# ### CRSP

# %%
#import wrds
#db = wrds.Connection()
lib = db.list_libraries()
crsp = [x for x in lib if 'crsp' in x]
crsp



#crsp = list(filter(lambda x: 'crsp' in x, lib))
#crsp

#import re
#crsp = [x for x in lib if re.search('crsp', x)]
#crsp
# Out:
# ['crsp',
#  'crsp_a_ccm',
#  'crsp_a_indexes',
#  'crsp_a_stock',
#  'crsp_q_indexes',
#  'crsp_q_indexhist',
#  'crsp_q_mutualfunds',
#  'crspq',
#  'crspsamp',
#  'crspsamp_all',
#  'crspsamp_mf',
#  'wrdsapps_link_crsp_bond',
#  'wrdsapps_link_crsp_comp_bdx',
#  'wrdsapps_link_crsp_factset',
#  'wrdsapps_link_crsp_ibes',
#  'wrdsapps_link_crsp_optionm',
#  'wrdsapps_link_crsp_taq',
#  'wrdsapps_link_crsp_taqm']

# %%
#import wrds
#db = wrds.Connection()
tables = db.list_tables(library='crsp')
tables
# Out:
# ['acti',
#  'asia',
#  'asib',
#  'asic',
#  'asio',
#  'asix',
#  'bmdebt',
#  'bmheader',
#  'bmpaymts',
#  'bmquotes',
#  'bmyield',
#  'bndprt06',
#  'bndprt12',
#  'bxcalind',
#  'bxdlyind',
#  'bxmthind',
#  'bxquotes',
#  'bxyield',
#  'cap',
#  'ccm_lookup',
#  'ccm_qvards',
#  'ccmxpf_linktable',
#  'ccmxpf_lnkhist',
#  'ccmxpf_lnkrng',
#  'ccmxpf_lnkused',
#  'comphead',
#  'comphist',
#  'compmaster',
#  'contact_info',
#  'core',
#  'crsp_cik_map',
#  'crsp_daily_data',
#  'crsp_header',
#  'crsp_monthly_data',
#  'crsp_names',
#  'crsp_portno_map',
#  'crsp_ziman_daily_index',
#  'crsp_ziman_monthly_index',
#  'cs20yr',
#  'cs5yr',
#  'cs90d',
#  'cst_hist',
#  'daily_nav',
#  'daily_nav_ret',
#  'daily_returns',
#  'dividends',
#  'dport1',
#  'dport2',
#  'dport3',
#  'dport4',
#  'dport5',
#  'dport6',
#  'dport7',
#  'dport8',
#  'dport9',
#  'dsbc',
#  'dsbo',
#  'dse',
#  'dse62',
#  'dse62delist',
#  'dse62dist',
#  'dse62exchdates',
#  'dse62names',
# ...

# %%
#import wrds
#db = wrds.Connection()
tables = db.list_tables(library='crsp_a_stock')
tables
# Out:
# ['dse',
#  'dseall',
#  'dsedelist',
#  'dsedist',
#  'dseexchdates',
#  'dsenames',
#  'dsenasdin',
#  'dseshares',
#  'dsf',
#  'dsf_v2',
#  'dsfhdr',
#  'dsi',
#  'dsiy',
#  'inddlyseriesdata',
#  'indfamilyinfohdr',
#  'indmthseriesdata',
#  'indseriesinfohdr',
#  'metacalendarperiod',
#  'metacolumncoverage',
#  'metacolumninfo',
#  'metaexchangecalendar',
#  'metafileinfo',
#  'metaflagcoverage',
#  'metaflaginfo',
#  'metaflagtype',
#  'metaiteminfo',
#  'metasiztociz',
#  'mse',
#  'mseall',
#  'msedelist',
#  'msedist',
#  'mseexchdates',
#  'msenames',
#  'msenasdin',
#  'mseshares',
#  'msf',
#  'msf_v2',
#  'msfhdr',
#  'msi',
#  'msiy',
#  'saz_agg_ann',
#  'saz_agg_ann_legacy',
#  'saz_agg_mth',
#  'saz_agg_mth_legacy',
#  'saz_agg_qtr',
#  'saz_agg_qtr_legacy',
#  'saz_del',
#  'saz_del_legacy',
#  'saz_dind',
#  'saz_dind_legacy',
#  'saz_dis',
#  'saz_dis_legacy',
#  'saz_dp_dly',
#  'saz_dp_dly_legacy',
#  'saz_ds_dly',
#  'saz_ds_dly_legacy',
#  'saz_hdr',
# ...

# %%
#import wrds
#db = wrds.Connection()
tables = db.list_tables(library='crsp_a_stock')

#open file in write mode
with open(r'tables_OF_crsp_a_stock_26_0907.txt', 'w') as a:

    for b in tables:
        #write each item on a new line
        a.write("%s\n" % b)
    print()

# %%
#import wrds
#db = wrds.Connection()
column_headers = db.describe_table(library='crsp_a_stock', table='wrds_msfv2_query')
#column_headers
print(column_headers.to_string())

#import wrds
#db = wrds.Connection()
#db.describe_table(library='crsp_a_stock', table='wrds_msfv2_query')
# Out:
# Approximately 5306839 rows in crsp_a_stock.wrds_msfv2_query.
#                    name  nullable             type                                     comment
# 0                permno      True          INTEGER                                      PERMNO
# 1        secinfostartdt      True             DATE             Security Information Start Date
# 2          secinfoenddt      True             DATE               Security Information End Date
# 3         securitybegdt      True             DATE                    Begin Date of Stock Data
# 4         securityenddt      True             DATE                      End Date of Stock Data
# 5        securityhdrflg      True       VARCHAR(1)                        Security Header Flag
# 6              hdrcusip      True       VARCHAR(8)                  Header CUSIP -8 Characters
# 7             hdrcusip9      True       VARCHAR(9)                  Header CUSIP -9 Characters
# ...

# %%
#import wrds
#db = wrds.Connection()
db.get_row_count(library='crsp_a_stock', table='wrds_msfv2_query')
#db.get_row_count('crsp_a_stock', 'wrds_msfv2_query')
# Out:
# 5306839

# %%
#pip install wrds

#import wrds
#db = wrds.Connection()

#db.list_libraries()

#db.list_tables(library='crsp_a_stock')
#db.list_tables('crsp_a_stock')

#db.describe_table(library='crsp_a_stock', table='wrds_msfv2_query')
#db.describe_table('crsp_a_stock','wrds_msfv2_query')

#db.get_row_count(library='crsp_a_stock', table='wrds_msfv2_query')
#db.get_row_count('crsp_a_stock', 'wrds_msfv2_query')

# %%
#import wrds
#import pandas
#db = wrds.Connection()

#db.get_table(library='crsp_a_stock', table='wrds_msfv2_query')
db.get_table(library='crsp_a_stock', table='wrds_msfv2_query', obs=10)
# Out:
#    permno secinfostartdt secinfoenddt securitybegdt securityenddt  \
# 0   10000     1986-01-07   1986-12-03    1986-01-07    1987-06-11
# 1   10000     1986-01-07   1986-12-03    1986-01-07    1987-06-11
# 2   10000     1986-01-07   1986-12-03    1986-01-07    1987-06-11
# 3   10000     1986-01-07   1986-12-03    1986-01-07    1987-06-11
# 4   10000     1986-01-07   1986-12-03    1986-01-07    1987-06-11
# 5   10000     1986-01-07   1986-12-03    1986-01-07    1987-06-11
# 6   10000     1986-01-07   1986-12-03    1986-01-07    1987-06-11
# 7   10000     1986-01-07   1986-12-03    1986-01-07    1987-06-11
# 8   10000     1986-01-07   1986-12-03    1986-01-07    1987-06-11
# 9   10000     1986-01-07   1986-12-03    1986-01-07    1987-06-11
#
#   securityhdrflg  hdrcusip  hdrcusip9     cusip     cusip9  ... disrecorddt  \
# 0              N  68391610  683916100  68391610  683916100  ...        <NA>
# 1              N  68391610  683916100  68391610  683916100  ...        <NA>
# ...

# %%
#import wrds
#db = wrds.Connection()
column_headers = db.describe_table(library='crsp_a_stock', table='wrds_msfv2_query')
#column_headers
print(column_headers.to_string())

#import wrds
#db = wrds.Connection()
#db.describe_table(library='crsp_a_stock', table='wrds_msfv2_query')
# Out:
# Approximately 5306839 rows in crsp_a_stock.wrds_msfv2_query.
#                    name  nullable             type                                     comment
# 0                permno      True          INTEGER                                      PERMNO
# 1        secinfostartdt      True             DATE             Security Information Start Date
# 2          secinfoenddt      True             DATE               Security Information End Date
# 3         securitybegdt      True             DATE                    Begin Date of Stock Data
# 4         securityenddt      True             DATE                      End Date of Stock Data
# 5        securityhdrflg      True       VARCHAR(1)                        Security Header Flag
# 6              hdrcusip      True       VARCHAR(8)                  Header CUSIP -8 Characters
# 7             hdrcusip9      True       VARCHAR(9)                  Header CUSIP -9 Characters
# ...

# %%
#import wrds
#db = wrds.Connection()
apple = db.raw_sql("""select count (*)
                        from crsp_a_stock.wrds_msfv2_query
                   """)
apple
# Out:
#      count
# 0  5307138

# %%
#import wrds
#db = wrds.Connection()
apple = db.raw_sql("""select permco, permno, ticker, mthcaldt, mthprc, mthret, shrout
                        from crsp_a_stock.wrds_msfv2_query
                       where permno = 14593
                         and mthcaldt>='01/01/2021'
                         and mthcaldt<='12/31/2021'
                   """)
apple
# Out:
#     permco  permno ticker    mthcaldt  mthprc    mthret    shrout
# 0        7   14593   AAPL  2021-01-29  131.96 -0.005502  16788096
# 1        7   14593   AAPL  2021-02-26  121.26 -0.079708  16788096
# 2        7   14593   AAPL  2021-03-31  122.15   0.00734  16686305
# 3        7   14593   AAPL  2021-04-30  131.46  0.076218  16687631
# 4        7   14593   AAPL  2021-05-28  124.61 -0.050506  16687631
# 5        7   14593   AAPL  2021-06-30  136.96  0.099109  16556942
# 6        7   14593   AAPL  2021-07-30  145.86  0.064983  16530166
# 7        7   14593   AAPL  2021-08-31  151.83  0.042497  16530166
# 8        7   14593   AAPL  2021-09-30   141.5 -0.068037  16426786
# 9        7   14593   AAPL  2021-10-29   149.8  0.058657  16406397
# 10       7   14593   AAPL  2021-11-30   165.3  0.105076  16406397
# 11       7   14593   AAPL  2021-12-31  177.57  0.074229  16344923

# %%
type(apple)
# Out:
# pandas.core.frame.DataFrame

# %%
apple.to_csv('apple.csv')

# %%
import pandas as pd
df = pd.read_csv('apple.csv')
print(df.to_string())
# Out:
#     Unnamed: 0  permco  permno ticker    mthcaldt  mthprc    mthret    shrout
# 0            0       7   14593   AAPL  2021-01-29  131.96 -0.005502  16788096
# 1            1       7   14593   AAPL  2021-02-26  121.26 -0.079708  16788096
# 2            2       7   14593   AAPL  2021-03-31  122.15  0.007340  16686305
# 3            3       7   14593   AAPL  2021-04-30  131.46  0.076218  16687631
# 4            4       7   14593   AAPL  2021-05-28  124.61 -0.050506  16687631
# 5            5       7   14593   AAPL  2021-06-30  136.96  0.099109  16556942
# 6            6       7   14593   AAPL  2021-07-30  145.86  0.064983  16530166
# 7            7       7   14593   AAPL  2021-08-31  151.83  0.042497  16530166
# 8            8       7   14593   AAPL  2021-09-30  141.50 -0.068037  16426786
# 9            9       7   14593   AAPL  2021-10-29  149.80  0.058657  16406397
# 10          10       7   14593   AAPL  2021-11-30  165.30  0.105076  16406397
# ...

# %%
#import wrds
#db = wrds.Connection()
apple_ibm = db.raw_sql("""select distinct permco, permno, ticker, mthcaldt, mthprc, mthret, shrout
                            from crsp_a_stock.wrds_msfv2_query
                         --where permno = 14593
                           where permno in ('14593', '12490')
                             and mthcaldt>='01/01/2021'
                             and mthcaldt<='12/31/2021'
                      """)
apple_ibm
# Out:
#     permco  permno ticker    mthcaldt  mthprc    mthret    shrout
# 0        7   14593   AAPL  2021-01-29  131.96 -0.005502  16788096
# 1        7   14593   AAPL  2021-02-26  121.26 -0.079708  16788096
# 2        7   14593   AAPL  2021-03-31  122.15   0.00734  16686305
# 3        7   14593   AAPL  2021-04-30  131.46  0.076218  16687631
# 4        7   14593   AAPL  2021-05-28  124.61 -0.050506  16687631
# 5        7   14593   AAPL  2021-06-30  136.96  0.099109  16556942
# 6        7   14593   AAPL  2021-07-30  145.86  0.064983  16530166
# 7        7   14593   AAPL  2021-08-31  151.83  0.042497  16530166
# 8        7   14593   AAPL  2021-09-30   141.5 -0.068037  16426786
# 9        7   14593   AAPL  2021-10-29   149.8  0.058657  16406397
# 10       7   14593   AAPL  2021-11-30   165.3  0.105076  16406397
# 11       7   14593   AAPL  2021-12-31  177.57  0.074229  16344923
# 12   20990   12490    IBM  2021-01-29  119.11 -0.053781    891057
# ...

# %%
#db.list_tables(library='crsp_q_mutualfunds')
#db.describe_table(library='crsp_q_mutualfunds', table='fund_summary2')

mfs = db.raw_sql("""--select *
                      select fund_name, ticker, first_offer_dt, mgmt_fee
                        from crsp_q_mutualfunds.fund_summary2""")
mfs
# Out:
#                                                fund_name ticker  \
# 0                         AARP Income Tr:Bond for Income  AABIX
# 1                         AARP Income Tr:Bond for Income  AABIX
# 2                         AARP Income Tr:Bond for Income  AABIX
# 3                         AARP Income Tr:Bond for Income  AABIX
# 4                         AARP Income Tr:Bond for Income  AABIX
# ...                                                  ...    ...
# 16624  Innovator ETFs Trust: Innovator Equity Dual Di...   DDFZ
# 16625    ETF Opportunities Trust: Hedgeye Index Adds ETF   ADDS
# 16626  Investment Managers Series Trust II: Tradr 2X ...   NXPX
# 16627  Investment Managers Series Trust II: Tradr 2X ...   MCHU
# 16628  Investment Managers Series Trust II: Tradr 2X ...    ONX
#
#       first_offer_dt  mgmt_fee
# 0         1997-02-01    -0.282
# 1         1997-02-01     0.084
# 2         1997-02-01     0.084
# 3         1997-02-01     0.084
# 4         1997-02-01     0.084
# ...

# %%
#db.list_tables(library='crsp_q_mutualfunds')
#db.describe_table(library='crsp_q_mutualfunds', table='fund_summary2')

mfs = db.raw_sql("""--select *
                      select fund_name, ticker, first_offer_dt, mgmt_fee
                        from crsp_q_mutualfunds.fund_summary2
                       LIMIT 03
                 """)
mfs
# Out:
#                         fund_name ticker first_offer_dt  mgmt_fee
# 0  AARP Income Tr:Bond for Income  AABIX     1997-02-01    -0.282
# 1  AARP Income Tr:Bond for Income  AABIX     1997-02-01     0.084
# 2  AARP Income Tr:Bond for Income  AABIX     1997-02-01     0.084

# %%
#db.get_table(library='crsp_q_mutualfunds', table='fund_summary2', obs=3)
db.get_table(library='crsp_q_mutualfunds', table='fund_summary2', columns = ['fund_name', 'ticker', 'first_offer_dt', 'mgmt_fee'], obs=3)
# Out:
#                         fund_name ticker first_offer_dt  mgmt_fee
# 0  AARP Income Tr:Bond for Income  AABIX     1997-02-01    -0.282
# 1  AARP Income Tr:Bond for Income  AABIX     1997-02-01     0.084
# 2  AARP Income Tr:Bond for Income  AABIX     1997-02-01     0.084

# %%
#import wrds
#db = wrds.Connection()
c = db.raw_sql(""" select ticker, issuernm, permco, permno, cusip, secinfostartdt, secinfoenddt, securitybegdt, securityenddt
                     from crsp_a_stock.wrds_names_query
                    where permno = 14593 """, date_cols=['secinfostartdt', 'secinfoenddt', 'securitybegdt', 'securityenddt'])

c = c.loc[c.ticker.notnull()].sort_values(by=['secinfostartdt', 'permno','ticker'])
c
# Out:
#    ticker            issuernm  permco  permno     cusip secinfostartdt  \
# 0    AAPL  APPLE COMPUTER INC       7   14593  03783310     1980-12-12
# 1    AAPL  APPLE COMPUTER INC       7   14593  03783310     1982-04-01
# 2    AAPL  APPLE COMPUTER INC       7   14593  03783310     1982-11-01
# 3    AAPL  APPLE COMPUTER INC       7   14593  03783310     2004-06-10
# 4    AAPL  APPLE COMPUTER INC       7   14593  03783310     2006-07-03
# 5    AAPL           APPLE INC       7   14593  03783310     2007-01-11
# 6    AAPL           APPLE INC       7   14593  03783310     2009-03-27
# 7    AAPL           APPLE INC       7   14593  03783310     2017-12-28
# 8    AAPL           APPLE INC       7   14593  03783310     2021-12-09
# 9    AAPL           APPLE INC       7   14593  03783310     2023-09-29
# 10   AAPL           APPLE INC       7   14593  03783310     2023-10-01
#
#    secinfoenddt securitybegdt securityenddt
# 0    1982-03-31    1980-12-12    2025-12-31
# ...

# %%
#import wrds
#db = wrds.Connection()
c = db.raw_sql(""" select ticker, issuernm, permco, permno, cusip, secinfostartdt, secinfoenddt, securitybegdt, securityenddt
                     from crsp_a_stock.wrds_names_query
                    where permno = 14593
                 order by secinfostartdt, permno, ticker """)
c
# Out:
#    ticker            issuernm  permco  permno     cusip secinfostartdt  \
# 0    AAPL  APPLE COMPUTER INC       7   14593  03783310     1980-12-12
# 1    AAPL  APPLE COMPUTER INC       7   14593  03783310     1982-04-01
# 2    AAPL  APPLE COMPUTER INC       7   14593  03783310     1982-11-01
# 3    AAPL  APPLE COMPUTER INC       7   14593  03783310     2004-06-10
# 4    AAPL  APPLE COMPUTER INC       7   14593  03783310     2006-07-03
# 5    AAPL           APPLE INC       7   14593  03783310     2007-01-11
# 6    AAPL           APPLE INC       7   14593  03783310     2009-03-27
# 7    AAPL           APPLE INC       7   14593  03783310     2017-12-28
# 8    AAPL           APPLE INC       7   14593  03783310     2021-12-09
# 9    AAPL           APPLE INC       7   14593  03783310     2023-09-29
# 10   AAPL           APPLE INC       7   14593  03783310     2023-10-01
#
#    secinfoenddt securitybegdt securityenddt
# 0    1982-03-31    1980-12-12    2025-12-31
# ...

# %%
apple_ret = db.raw_sql("""select
                                --permno,
                                  mthcaldt,
                                --prc,
                                  mthret--,
                                --shrout
                            from crsp_a_stock.wrds_msfv2_query
                           where permno = 14593
                             and mthcaldt>='01/01/1980'
                             and mthcaldt<='12/31/2025'
                        order by mthcaldt""",
                                 date_cols=['mthcaldt'], index_col=['mthcaldt'])
apple_ret
# Out:
#               mthret
# mthcaldt
# 1980-12-31  0.186551
# 1981-01-30 -0.170018
# 1981-02-27 -0.061674
# 1981-03-31 -0.075117
# 1981-04-30   0.15736
# ...              ...
# 2025-08-29   0.11965
# 2025-09-30  0.096881
# 2025-10-31  0.061815
# 2025-11-28   0.03236
# 2025-12-31 -0.025067
#
# [542 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(apple_ret)
plt.xlabel('mthcaldt')
plt.ylabel('mthret')
plt.show()

# %%
#db.list_libraries()
#db.list_tables()
#db.describe_table()
#db.get_row_count()
#db.get_table()
#db.raw_sql()

# %%
help(db.list_libraries)
#help(db.list_tables)
#help(db.describe_table)
#help(db.get_row_count)
#help(db.get_table)
#help(db.raw_sql)
# Out:
# Help on method list_libraries in module wrds.sql:
#
# list_libraries() method of wrds.sql.Connection instance
#     Return all the libraries (schemas) the user can access.
#
#     :rtype: list
#
#     Usage::
#     >>> db.list_libraries()
#     ['aha', 'audit', 'block', 'boardex', ...]

# %%
#help(db.list_libraries)
#help(db.list_tables)
#help(db.describe_table)
#help(db.get_row_count)
#help(db.get_table)
help(db.raw_sql)
# Out:
# Help on method raw_sql in module wrds.sql:
#
# raw_sql(
#     sql,
#     coerce_float=True,
#     date_cols=None,
#     index_col=None,
#     params=None,
#     chunksize=500000,
#     return_iter=False,
#     dtype=None,
#     dtype_backend='numpy_nullable'
# ) method of wrds.sql.Connection instance
#     Queries the database using a raw SQL string.
#
#     :param sql: SQL code in string object.
#     :param coerce_float: (optional) boolean, default: True
#         Attempts to convert values of non-string, non-numeric objects
#         to floating point. Can result in loss of precision.
#     :param date_cols: (optional) list or dict, default: None
#         - List of column names to parse as date
#         - Dict of ``{column_name: format string}`` where
#             format string is:
#               strftime compatible in case of parsing string times or
#               is one of (D, s, ns, ms, us) in case of parsing
#                 integer timestamps
# ...

# %%
# Apple Inc's Stock Splits 4-1, 7-1, 2-1, 2-1, and 2-1
query = """
          SELECT dlycaldt     AS "Date",
                 dlyfacprc    AS "Price Adj. Factor",
               --dlycumfacpr  AS "Cumulative Price Adj. Factor",
                 dlycumfacshr AS "Cumulative Share Adj. Factor",
                 prev_dlycumfacshr/dlycumfacshr AS "prev_dlycumfacshr/dlycumfacshr"
            FROM (
                  SELECT dlycaldt,
                         dlyfacprc,
                       --dlycumfacpr,
                         dlycumfacshr,
                         LAG(dlycumfacshr) OVER (PARTITION BY permno ORDER BY dlycaldt) AS "prev_dlycumfacshr"
                    FROM crsp_a_stock.dsf_v2
                   WHERE permno = 14593
                 ) sub
           WHERE dlycumfacshr IS DISTINCT FROM prev_dlycumfacshr
        ORDER BY dlycaldt
        """
apple_stock_split = db.raw_sql(query)
apple_stock_split
# Out:
#          Date  Price Adj. Factor  Cumulative Share Adj. Factor  \
# 0  1980-12-12                1.0                         224.0
# 1  1987-06-16                2.0                         112.0
# 2  2000-06-21                2.0                          56.0
# 3  2005-02-28                2.0                          28.0
# 4  2014-06-09                7.0                           4.0
# 5  2020-08-31                4.0                           1.0
#
#    prev_dlycumfacshr/dlycumfacshr
# 0                            <NA>
# 1                             2.0
# 2                             2.0
# 3                             2.0
# 4                             7.0
# 5                             4.0

# %%
# LogicMark Inc's Reverse Stock Splits 1-25, 1-20, 1-10, and 1-10
query = """
          SELECT dlycaldt     AS "Date",
                 dlyfacprc    AS "Price Adj. Factor",
               --dlycumfacpr  AS "Cumulative Price Adj. Factor",
                 dlycumfacshr AS "Cumulative Share Adj. Factor",
                 prev_dlycumfacshr/dlycumfacshr AS "prev_dlycumfacshr/dlycumfacshr"
            FROM (
                  SELECT dlycaldt,
                         dlyfacprc,
                       --dlycumfacpr,
                         dlycumfacshr,
                         LAG(dlycumfacshr) OVER (PARTITION BY permno ORDER BY dlycaldt) AS "prev_dlycumfacshr"
                    FROM crsp_a_stock.dsf_v2
                   WHERE permno = 14934
                 ) sub
           WHERE dlycumfacshr IS DISTINCT FROM prev_dlycumfacshr
        ORDER BY dlycaldt
        """
logicmark_reverse_split = db.raw_sql(query)
logicmark_reverse_split
# Out:
#          Date  Price Adj. Factor  Cumulative Share Adj. Factor  \
# 0  2014-09-11                1.0                       0.00002
# 1  2016-09-12                0.1                        0.0002
# 2  2021-10-18                0.1                         0.002
# 3  2023-04-24               0.05                          0.04
# 4  2024-11-19               0.04                           1.0
# 5  2025-06-02                1.0                          <NA>
#
#    prev_dlycumfacshr/dlycumfacshr
# 0                            <NA>
# 1                             0.1
# 2                             0.1
# 3                            0.05
# 4                            0.04
# 5                            <NA>

# %%
# Barnes & Noble Education Inc's 1-for-100 Reverse Stock Split
# Prc / Cumulative Prc Adj Factor
# Shrout * Cumulative Shr ADj Factor
BNED = db.raw_sql("""SELECT --permno,
                            --SUBSTRING(dlycaldt::TEXT, 1, 4) AS year,
                              dlycaldt,
                              dlyprc,
                            --dlyfacprc,
                              dlycumfacpr,
                              dlyprc/dlycumfacpr   AS "dlyprc/dlycumfacpr",
                              shrout,
                              dlycumfacshr,
                              shrout*dlycumfacshr  AS "shrout*dlycumfacshr"
                       FROM   crsp_a_stock.dsf_v2
                      WHERE   permno = 15489
                        AND   dlycaldt >= '2024-06-07'
                        AND   dlycaldt <= '2024-06-17'
                   ORDER BY   1
                  """)
BNED
# Out:
#      dlycaldt  dlyprc  dlycumfacpr  dlyprc/dlycumfacpr  shrout  dlycumfacshr  \
# 0  2024-06-07  0.1733         0.01               17.33   53156          0.01
# 1  2024-06-10   0.134         0.01                13.4   53156          0.01
# 2  2024-06-11  0.0943         0.01                9.43   53156          0.01
# 3  2024-06-12    6.99          1.0                6.99     532           1.0
# 4  2024-06-13    9.32          1.0                9.32     532           1.0
# 5  2024-06-14    8.65          1.0                8.65     532           1.0
# 6  2024-06-17    8.08          1.0                8.08     532           1.0
#
#    shrout*dlycumfacshr
# 0               531.56
# 1               531.56
# 2               531.56
# 3                532.0
# 4                532.0
# 5                532.0
# 6                532.0

# %%
# CRSP’s S&P 500 Index Constituents – Dual Class Shares on Last Trading Day of 2025
query = """
               SELECT a.permco, a.permno, a.shareclass, a.ticker
                 FROM crsp_a_stock.wrds_dsfv2_query a
           INNER JOIN crsp_a_indexes.dsp500list_v2  b
                   ON a.permno = b.permno
                WHERE a.dlycaldt = '12/31/2025'
                  AND b.mbrenddt = '12/31/2025'
             GROUP BY a.permco, a.permno, a.shareclass, a.ticker
               HAVING a.permco IN (
                                      SELECT c.permco
                                        FROM crsp_a_stock.wrds_dsfv2_query c
                                  INNER JOIN crsp_a_indexes.dsp500list_v2  d
                                          ON c.permno = d.permno
                                       WHERE c.dlycaldt = '12/31/2025'
                                         AND d.mbrenddt = '12/31/2025'
                                    GROUP BY c.permco
                                      HAVING COUNT(DISTINCT c.shareclass) > '1'
                                  )
             ORDER BY a.permco, a.shareclass
        """
sp500_dual_class_share = db.raw_sql(query)
sp500_dual_class_share
# Out:
#    permco  permno shareclass ticker
# 0   45483   90319          A  GOOGL
# 1   45483   14542          C   GOOG
# 2   54433   13963          A   NWSA
# 3   54433   13964          B    NWS
# 4   56662   18420          A   FOXA
# 5   56662   18421          B    FOX

# %%
###

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
###

# %%
#CAUTION
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = None
display(apple_ret)
# Out:
#               mthret
# mthcaldt
# 1980-12-31  0.186551
# 1981-01-30 -0.170018
# 1981-02-27 -0.061674
# 1981-03-31 -0.075117
# 1981-04-30   0.15736
# 1981-05-29  0.164474
# 1981-06-30 -0.214689
# 1981-07-31 -0.038369
# 1981-08-31 -0.194514
# 1981-09-30 -0.241486
# 1981-10-30  0.310204
# 1981-11-30 -0.068536
# 1981-12-31  0.187291
# 1982-01-29 -0.078873
# 1982-02-26 -0.103976
# 1982-03-31 -0.075085
# 1982-04-30 -0.125461
# 1982-05-28 -0.050633
# 1982-06-30 -0.088889
# 1982-07-30  0.058537
# 1982-08-31  0.331797
# 1982-09-30  0.013841
# 1982-10-29  0.385666
# 1982-11-30  0.256158
# 1982-12-31 -0.062745
# 1983-01-31  0.368201
# 1983-02-28  0.116208
# 1983-03-31 -0.073973
# 1983-04-29  0.195266
# 1983-05-31  0.143564
# 1983-06-30  -0.15368
# 1983-07-29 -0.286445
# 1983-08-31    0.0681
# 1983-09-30 -0.379195
# 1983-10-31 -0.021622
# 1983-11-30 -0.099448
# 1983-12-30  0.196319
# 1984-01-31  0.015385
# 1984-02-29  0.060606
# 1984-03-30 -0.057143
# 1984-04-30  0.267677
# 1984-05-31 -0.063745
# ...

# %%
import pandas as pd

# Reset the display options to default
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')

# %% [markdown]
# ### EXTRA: CRSP's S&P 500 Historical Constituents

# %%
#All 557 constituents of S&P 500 that were members at any time during the 3-year period between 2022 and 2024 (correct as at query time)
sp500 = db.raw_sql("""
                              select permno, mbrstartdt, mbrenddt
                                from crsp_a_indexes.dsp500list_v2
                               where not (mbrenddt < '01/01/2022')
                            order by 3, 2
                   """)
sp500
# Out:
#      permno  mbrstartdt    mbrenddt
# 0     59010  1986-08-21  2022-02-02
# 1     76201  1999-11-08  2022-02-14
# 2     14704  2017-06-02  2022-03-01
# 3     12073  2008-11-13  2022-04-01
# 4     90805  2010-03-01  2022-04-08
# ..      ...         ...         ...
# 572   26181  2025-11-28  2025-12-31
# 573   14617  2025-12-11  2025-12-31
# 574   85059  2025-12-22  2025-12-31
# 575   16655  2025-12-22  2025-12-31
# 576   24294  2025-12-22  2025-12-31
#
# [577 rows x 3 columns]

# %%
#All 557 constituents of S&P 500 that were members at any time during the 3-year period between 2022 and 2024 grouped by member end date (correct as at query time)
sp500 = db.raw_sql("""
                              select mbrenddt, count(*)
                                from crsp_a_indexes.dsp500list_v2
                               where not (mbrenddt < '01/01/2022')
                            group by mbrenddt
                            order by 1
                   """)
sp500
# Out:
#       mbrenddt  count
# 0   2022-02-02      1
# 1   2022-02-14      1
# 2   2022-03-01      1
# 3   2022-04-01      1
# 4   2022-04-08      2
# 5   2022-06-07      1
# 6   2022-06-17      3
# 7   2022-09-16      2
# 8   2022-09-30      2
# 9   2022-10-11      1
# 10  2022-10-31      1
# 11  2022-12-16      2
# 12  2022-12-21      1
# 13  2023-01-04      1
# 14  2023-03-14      2
# 15  2023-03-17      1
# 16  2023-05-03      1
# 17  2023-06-16      1
# 18  2023-07-05      2
# 19  2023-08-24      1
# 20  2023-09-15      2
# 21  2023-10-02      2
# 22  2023-10-17      2
# 23  2023-12-15      3
# 24  2024-03-15      2
# 25  2024-04-02      2
# 26  2024-05-07      1
# 27  2024-06-21      3
# 28  2024-07-05      1
# 29  2024-09-20      3
# 30  2024-09-30      1
# 31  2024-11-25      1
# 32  2024-12-20      3
# 33  2025-03-21      4
# 34  2025-05-16      1
# 35  2025-07-08      1
# 36  2025-07-17      1
# 37  2025-07-22      1
# 38  2025-08-06      1
# 39  2025-08-27      1
# ...

# %%
#All 557 constituents of S&P 500 that were members at any time during the 3-year period between 2022 and 2024 grouped by member start date (correct as at query time)
sp500 = db.raw_sql("""
                              select mbrstartdt, count(*)
                                from crsp_a_indexes.dsp500list_v2
                               where not (mbrenddt < '01/01/2022')
                            group by mbrstartdt
                            order by 1
                   """)
sp500
# Out:
#      mbrstartdt  count
# 0    1925-12-31      8
# 1    1944-06-07      2
# 2    1948-07-07      1
# 3    1949-07-06      1
# 4    1951-09-06      1
# ..          ...    ...
# 436  2025-10-30      1
# 437  2025-11-03      1
# 438  2025-11-28      1
# 439  2025-12-11      1
# 440  2025-12-22      3
#
# [441 rows x 2 columns]

# %%
#All 8 constituents of S&P 500 that were members at any time during the 3-year period between 2022 and 2024 where member start date = 31 Dec 1925 (correct as at query time)
sp500 = db.raw_sql("""
                              select permno, mbrstartdt, mbrenddt
                                from crsp_a_indexes.dsp500list_v2
                               where not (mbrenddt < '01/01/2022')
                                 and mbrstartdt = '12/31/1925'
                            order by 3, 2
                   """)
sp500
# Out:
#    permno  mbrstartdt    mbrenddt
# 0   15069  1925-12-31  2024-11-25
# 1   11404  1925-12-31  2025-12-31
# 2   11674  1925-12-31  2025-12-31
# 3   11850  1925-12-31  2025-12-31
# 4   14541  1925-12-31  2025-12-31
# 5   15720  1925-12-31  2025-12-31
# 6   10145  1925-12-31  2025-12-31
# 7   21573  1925-12-31  2025-12-31

# %% [markdown]
# Article: Notes and Thoughts on Retrieving Historical Members of S&P 500 from WRDS
#
# https://ink.library.smu.edu.sg/library_research/231/
